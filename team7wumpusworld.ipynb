# %%
import random

grid = [[[] for _ in range(6)] for _ in range(6)]

for i in range(6):
    grid[0][i] = 'wall'
for i in range(6):
    grid[5][i] = 'wall'
for i in range(6):
    grid[i][0] = 'wall'
for i in range(6):
    grid[i][5] = 'wall'
    
grid1 = [[[] for _ in range(6)] for _ in range(6)]

for i in range(6):
    grid1[0][i] = 'wall'
for i in range(6):
    grid1[5][i] = 'wall'
for i in range(6):
    grid1[i][0] = 'wall'
for i in range(6):
    grid1[i][5] = 'wall'
    
agent = [1, 1]
direction = 'East' 
arrows = 2
path = []

def place_gold():
    empty_cells = [(i, j) for i in range(1, 5) for j in range(1, 5) if not (i == 1 and j == 1) and not (i == 2 and j == 1) and not (i == 1 and j == 2)]
    random_cell = random.choice(empty_cells)
    grid[random_cell[0]][random_cell[1]] = 'gold'

def place_pits():
    empty_cells = [(i, j) for i in range(1, 5) for j in range(1, 5) if not (i == 1 and j == 1) and not (i == 2 and j == 1) and not (i == 1 and j == 2)]
    random.shuffle(empty_cells)  # 랜덤한 순서로 셀을 선택하기 위해 empty_cells를 섞습니다.

    for cell in empty_cells:
        if grid[cell[0]][cell[1]] != 'gold' and grid[cell[0]][cell[1]] != 'stench':
            grid[cell[0]][cell[1]] = 'pit'
            
            # 주변 칸에 stench 값을 설정합니다.
            adjacent_cells = [(cell[0]-1, cell[1]), (cell[0]+1, cell[1]), (cell[0], cell[1]-1), (cell[0], cell[1]+1)]
            for adj_cell in adjacent_cells:
                if adj_cell[0] in range(1, 5) and adj_cell[1] in range(1, 5) and grid[adj_cell[0]][adj_cell[1]] != 'gold':
                    grid[adj_cell[0]][adj_cell[1]] = 'breeze'
            return  # Wumpus를 배치한 후 함수 종료


def place_wumpus():
    empty_cells = [(i, j) for i in range(1, 5) for j in range(1, 5) if not (i == 1 and j == 1) and not (i == 2 and j == 1) and not (i == 1 and j == 2)]
    random.shuffle(empty_cells)  # 랜덤한 순서로 셀을 선택하기 위해 empty_cells를 섞습니다.

    for cell in empty_cells:
        if grid[cell[0]][cell[1]] != 'gold':
            grid[cell[0]][cell[1]] = 'wumpus'
            
            # 주변 칸에 stench 값을 설정합니다.
            adjacent_cells = [(cell[0]-1, cell[1]), (cell[0]+1, cell[1]), (cell[0], cell[1]-1), (cell[0], cell[1]+1)]
            for adj_cell in adjacent_cells:
                if adj_cell[0] in range(1, 5) and adj_cell[1] in range(1, 5) and grid[adj_cell[0]][adj_cell[1]] != 'gold':
                    grid[adj_cell[0]][adj_cell[1]] = 'stench'
            return  # Wumpus를 배치한 후 함수 종료

    


    
def print_grid():
    max_length = max(len(str(cell)) for row in grid for cell in row)
    line = '+' + '-' * (max_length + 2) + '+'
    print("Grid with initial setup")
    for i, row in enumerate(grid):
        print(line)
        for j, cell in enumerate(row):
            if [i, j] == agent:
                if direction == 'East':
                    print(f'| {"▷":^{max_length}}', end='')
                elif direction == 'North':
                    print(f'| {"△":^{max_length}}', end='')
                elif direction == 'South':
                    print(f'| {"▽":^{max_length}}', end='')
                elif direction == 'West':
                    print(f'| {"◁":^{max_length}}', end='')
            elif cell == 'wall':
                print(f'| {"wall":^{max_length}}', end=' ')
            elif cell == 'wumpus':
                print(f'| {"wumpus":^{max_length}}', end=' ')
            elif cell == 'pit':
                print(f'| {"pit":^{max_length}}', end=' ')
            elif cell == 'stench':
                print(f'| {"stench":^{max_length}}', end=' ')
            elif cell == 'breeze':
                print(f'| {"breeze":^{max_length}}', end=' ')
            else:
                print(f'| {str(cell):^{max_length}}', end=' ')
        print('|')
    print(line)
    print("Grid with updated information")
    for i, row in enumerate(grid1):
        print(line)
        for j, cell in enumerate(row):
            if [i, j] == agent:
                if direction == 'East':
                    print(f'| {"▷":^{max_length}}', end='')
                elif direction == 'North':
                    print(f'| {"△":^{max_length}}', end='')
                elif direction == 'South':
                    print(f'| {"▽":^{max_length}}', end='')
                elif direction == 'West':
                    print(f'| {"◁":^{max_length}}', end='')
            elif cell == 'wall':
                print(f'| {"wall":^{max_length}}', end=' ')
            elif cell == 'wumpus':
                print(f'| {"wumpus":^{max_length}}', end=' ')
            elif cell == 'pit':
                print(f'| {"pit":^{max_length}}', end=' ')
            elif cell == 'stench':
                print(f'| {"stench":^{max_length}}', end=' ')
            elif cell == 'breeze':
                print(f'| {"breeze":^{max_length}}', end=' ')
            else:
                print(f'| {str(cell):^{max_length}}', end=' ')
        print('|')
    print(line)
    print('\n\n')
    
def turnRight():
    global direction
    if direction == 'East':
        direction = 'South'
    elif direction == 'South':
        direction = 'West'
    elif direction == 'West':
        direction = 'North'
    elif direction == 'North':
        direction = 'East'

def turnLeft():
    global direction
    if direction == 'East':
        direction = 'North'
    elif direction == 'North':
        direction = 'West'
    elif direction == 'West':
        direction = 'South'
    elif direction == 'South':
        direction = 'East'
    
    
def goForward():
    global agent, direction, wumpus_position

    next_position = [agent[0], agent[1]]  # 현재 위치로 초기화

    if direction == 'East':
        next_position[1] += 1
    elif direction == 'West':
        next_position[1] -= 1
    elif direction == 'North':
        next_position[0] -= 1
    elif direction == 'South':
        next_position[0] += 1
        
        
    if grid1[next_position[0]][next_position[1]] != 'wall' and grid1[next_position[0]][next_position[1]] != 'wumpus' and grid1[next_position[0]][next_position[1]] != 'pit':
        agent = next_position
    elif grid[next_position[0]][next_position[1]] == 'wumpus':
        shoot()
    elif grid[next_position[0]][next_position[1]] == 'pit':
        if random.random() < 0.5:
            turnRight()
            goForward()
        else:
            turnLeft()
            goForward()
    elif grid[next_position[0]][next_position[1]] == 'wall':
        print("Bump!")
        if random.random() < 0.5:
            turnRight()
            goForward()
        else:
            turnLeft()
            goForward()
    else:
        agent = next_position



                
def shoot():
    global arrows, agent, direction
    if arrows > 0:
        arrows -= 1
        if direction == 'East':
            grid[agent[0]][agent[1]] = []
            grid1[agent[0]][agent[1]] = 'safe'
            grid[agent[0]][agent[1]+1] = []
            if grid[agent[0]-1][agent[1]+1] == 'stench':
                grid[agent[0]-1][agent[1]+1] = []
            if grid[agent[0]+1][agent[1]+1] == 'stench':
                grid[agent[0]+1][agent[1]+1] = []
            if grid[agent[0]][agent[1]+2] == 'stench':
                grid[agent[0]][agent[1]+2] = []
            print('Scream!')
            return
        elif direction == 'West':
            grid[agent[0]][agent[1]] = []
            grid1[agent[0]][agent[1]] = 'safe'
            grid[agent[0]][agent[1]-1] = []
            if grid[agent[0]-1][agent[1]-1] == 'stench':
                grid[agent[0]-1][agent[1]-1] = []
            if grid[agent[0]+1][agent[1]-1] == 'stench':
                grid[agent[0]+1][agent[1]-1] = []
            if grid[agent[0]][agent[1]-2] == 'stench':
                grid[agent[0]][agent[1]-2] = []
            print('Scream!')
            return
        elif direction == 'North':
            grid[agent[0]][agent[1]] = []
            grid1[agent[0]][agent[1]] = 'safe'
            grid[agent[0]-1][agent[1]] = []
            if grid[agent[0]-2][agent[1]-1] == 'stench':
                grid[agent[0]-2][agent[1]-1] = []
            if grid[agent[0]-2][agent[1]+1] == 'stench':
                grid[agent[0]-2][agent[1]+1] = []
            if grid[agent[0]-3][agent[1]] == 'stench':
                grid[agent[0]-3][agent[1]] = []
            print('Scream!')
            return
        elif direction == 'South':
            grid[agent[0]][agent[1]] = []
            grid1[agent[0]][agent[1]] = 'safe'
            grid[agent[0]+1][agent[1]] = []
            if grid[agent[0]+2][agent[1]-1] == 'stench':
                grid[agent[0]+2][agent[1]-1] = []
            if grid[agent[0]+2][agent[1]+1] == 'stench':
                grid[agent[0]+2][agent[1]+1] = []
            if grid[agent[0]+3][agent[1]] == 'stench':
                grid[agent[0]+3][agent[1]] = []
            print('Scream!')
            return
    else:
        print('No more arrows!')


        
def auto_play():
    global agent, direction, wumpus_position, pit_position
    grab_gold = False
    stack = []
    while True:
        print_grid()
        if grid[agent[0]][agent[1]] == 'gold':
            grab_gold = True
            print("glitter!!!")
            grid1[agent[0]][agent[1]] = 'gold'
            goForward()
            continue


        elif grid[agent[0]][agent[1]] == 'breeze':
            print("breeze!!")
            grid1[agent[0]][agent[1]] = 'breeze'  # Update grid1 with breeze
            goForward()
            stack.append(agent[:])
            continue
            
        elif grid[agent[0]][agent[1]] == 'stench':
            print("stench!!")
            grid1[agent[0]][agent[1]] = 'stench'  # Update grid1 with stench
            goForward()
            stack.append(agent[:])
            continue

        elif grid[agent[0]][agent[1]] == 'wumpus':
            print("Dead by wumpus")
            wumpus_position = agent[:]
            grid1[agent[0]][agent[1]] = 'wumpus'  # Update grid1 with wumpus
            agent = [1,1]
            direction = 'East'
            stack.clear()
            continue
        
        elif grid[agent[0]][agent[1]] == 'pit':
            print("Dead by pit")
            pit_position = agent[:]
            grid1[agent[0]][agent[1]] = 'pit'  # Update grid1 with pit
            agent = [1,1]
            direction = 'East'
            stack.clear()
            continue
            
        elif agent == [1,1] and grab_gold:
            print("Climb! You won the game!")
            break
            
        else:
            grid1[agent[0]][agent[1]] = 'safe'
            goForward()
            


            
place_gold()
place_wumpus()
place_pits()
print_grid()
# Out:
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   ▷   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   ▷   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+

# %%
auto_play()
# Out:
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   ▷   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   ▷   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   ▷   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |   ▷   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▷   |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  |   ▷   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# breeze!!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |   ▷   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |   ▷   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Dead by pit
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   ▷   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   ▷   |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   ▷   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |   ▷   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▷   |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  |   ▷   |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# breeze!!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▽   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▽   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# stench!!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   ▽   | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▽   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Dead by wumpus
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   ▷   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   ▷   |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   | wumpus |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   ▷   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |   ▷   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   | wumpus |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▷   |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  |   ▷   |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   | stench |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   | wumpus |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# breeze!!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▽   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench | wumpus | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▽   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   | wumpus |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# stench!!
# Scream!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▽   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   []   | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▽   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   | wumpus |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   ▽   | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▽   |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   []   | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▽   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ▽   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# glitter!!!
# Bump!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   []   | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   ▷   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   ▷   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Bump!
# Bump!
# Bump!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   []   |   △   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  |   []   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  |   △   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |  safe  |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# stench!!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   |   △   |  wall  |
# +--------+
# |  wall  |   []   | stench |   []   | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  |   △   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |  safe  |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# breeze!!
# Bump!
# Bump!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   []   |   ▽   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  | breeze |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  |   ▽   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |  safe  |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# stench!!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   []   | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   ▽   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  | breeze |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   ▽   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Bump!
# Bump!
# Bump!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   []   | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ◁   |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  | breeze |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |   ◁   |  safe  |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# glitter!!!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   []   | stench |  wall  |
# +--------+
# |  wall  |   []   |   ◁   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  | breeze |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  | stench |  wall  |
# +--------+
# |  wall  |   []   |   ◁   |  gold  |  safe  |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   []   | stench |  wall  |
# +--------+
# |  wall  |   ◁   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  | breeze |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  | stench |  wall  |
# +--------+
# |  wall  |   ◁   |  safe  |  gold  |  safe  |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Bump!
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   | breeze |  wall  |
# +--------+
# |  wall  |   △   | stench |   []   | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |  safe  | breeze |  wall  |
# +--------+
# |  wall  |   △   |   []   |  safe  | stench |  wall  |
# +--------+
# |  wall  |  safe  |  safe  |  gold  |  safe  |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   []   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   △   |   []   |   []   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   []   | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |  safe  |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   △   |   []   |  safe  | breeze |  wall  |
# +--------+
# |  wall  |  safe  |   []   |  safe  | stench |  wall  |
# +--------+
# |  wall  |  safe  |  safe  |  gold  |  safe  |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Grid with initial setup
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   △   |   []   | breeze |  pit   |  wall  |
# +--------+
# |  wall  |   []   |   []   |   []   | breeze |  wall  |
# +--------+
# |  wall  |   []   | stench |   []   | stench |  wall  |
# +--------+
# |  wall  |   []   |   []   |  gold  |   []   |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# Grid with updated information
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
# |  wall  |   △   |  safe  | breeze |  pit   |  wall  |
# +--------+
# |  wall  |  safe  |   []   |  safe  | breeze |  wall  |
# +--------+
# |  wall  |  safe  |   []   |  safe  | stench |  wall  |
# +--------+
# |  wall  |  safe  |  safe  |  gold  |  safe  |  wall  |
# +--------+
# |  wall  |  wall  |  wall  |  wall  |  wall  |  wall  |
# +--------+
#
#
#
# Climb! You won the game!
